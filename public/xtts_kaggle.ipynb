# %% [markdown]
# # 🎙️ XTTSv2 for Kaggle
#
# **Fast Voice Cloning** - 17 Languages!
#
# **Before running:**
# 1. Settings → Accelerator → **GPU T4 x2**
# 2. Settings → Internet → **ON**
# 3. Run cells with **Shift+Enter**

# %%
# !pip install -q torch torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q "coqui-tts[codec]" flask flask-cors pyngrok noisereduce

# %%
import os
os.environ['COQUI_TOS_AGREED'] = '1'

import torch
import transformers.pytorch_utils as _pu
if not hasattr(_pu, 'isin_mps_friendly'):
    _pu.isin_mps_friendly = torch.isin
    print('🔧 Patched missing isin_mps_friendly')

from TTS.api import TTS

print('🔄 Loading XTTSv2 model...')
print(f'   GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU"}')

tts = TTS('tts_models/multilingual/multi-dataset/xtts_v2').to('cuda')

print('✅ XTTSv2 loaded!')
print(f'   Languages: {tts.languages}')

# %%
# PASTE YOUR NGROK TOKEN HERE!
NGROK_TOKEN = ""  # <-- Get from https://dashboard.ngrok.com/get-started/your-authtoken

from pyngrok import ngrok
if NGROK_TOKEN:
    ngrok.set_auth_token(NGROK_TOKEN)
    print("✅ ngrok token set!")
else:
    print("⚠️ Enter your ngrok token above!")

# %%
from flask import Flask, request, send_file, jsonify, Response
from flask_cors import CORS
import soundfile as sf
import numpy as np
import noisereduce as nr
from scipy.signal import butter, sosfilt
import io, base64, tempfile, os, json, re

app = Flask(__name__)
CORS(app)

LANGUAGES = {
    "English": "en", "Chinese": "zh-cn", "Japanese": "ja", "Korean": "ko",
    "German": "de", "French": "fr", "Spanish": "es", "Italian": "it",
    "Portuguese": "pt", "Russian": "ru", "Arabic": "ar", "Hindi": "hi",
    "Turkish": "tr", "Polish": "pl", "Dutch": "nl", "Czech": "cs", "Hungarian": "hu"
}

NON_LATIN_LANGS = {'hi', 'zh-cn', 'ja', 'ko', 'ar'}

def clean_audio(audio, sr):
    # Aggressive noise removal
    cleaned = nr.reduce_noise(y=audio, sr=sr, prop_decrease=0.9, stationary=True, n_std_thresh_stationary=1.0)
    # High-pass filter 100Hz (removes more rumble)
    sos = butter(6, 100, btype='high', fs=sr, output='sos')
    cleaned = sosfilt(sos, cleaned)
    # Low-pass filter 8000Hz (removes high-frequency hiss)
    sos2 = butter(6, 8000, btype='low', fs=sr, output='sos')
    cleaned = sosfilt(sos2, cleaned)
    # Normalize
    peak = np.max(np.abs(cleaned))
    if peak > 0:
        cleaned = cleaned * (0.92 / peak)
    return cleaned.astype(np.float32)

def split_text_for_lang(text, lang_code='en'):
    """Split text into sentence-sized chunks. Hindi = ~50 chars, English = ~200."""
    max_chars = 50 if lang_code in NON_LATIN_LANGS else 200
    
    # Split on sentence endings (. ! ? , ; : newline + Hindi purna viram)
    parts = re.split(r'(?<=[।.!?;,:\n])\s*', text)
    
    chunks = []
    current = ""
    for p in parts:
        p = p.strip()
        if not p:
            continue
        if len(current) + len(p) + 1 <= max_chars:
            current += (" " if current else "") + p
        else:
            if current:
                chunks.append(current.strip())
            # Force-split overly long segments by words
            if len(p) > max_chars:
                words = p.split()
                sub = ""
                for w in words:
                    if len(sub) + len(w) + 1 <= max_chars:
                        sub += (" " if sub else "") + w
                    else:
                        if sub: chunks.append(sub.strip())
                        sub = w
                current = sub
            else:
                current = p
    if current:
        chunks.append(current.strip())
    return chunks if chunks else [text]

@app.route('/health', methods=['GET'])
def health():
    return jsonify({"status": "ok", "model": "XTTSv2", "gpu": torch.cuda.get_device_name(0)})

@app.route('/api/tts', methods=['POST'])
def generate_tts():
    data = request.json
    text = data.get('text', 'Hello')
    language = data.get('language', 'English')
    ref_audio_b64 = data.get('ref_audio')
    stream = data.get('stream', False)
    
    lang_code = LANGUAGES.get(language, 'en')

    def generate_with_progress():
        try:
            print(f"🎙️ lang={language} ({lang_code}), chars={len(text)}")
            
            chunks = split_text_for_lang(text, lang_code=lang_code)
            total = len(chunks)
            print(f"   {total} chunks (max {'50' if lang_code in NON_LATIN_LANGS else '200'} chars)")
            for idx, c in enumerate(chunks):
                print(f"   [{idx+1}] {len(c)}ch: {c[:80]}")
            
            yield f"data: {json.dumps({'type': 'progress', 'current': 0, 'total': total, 'percent': 0, 'status': 'Preparing...'})}\n\n"
            
            # Save reference audio
            with tempfile.NamedTemporaryFile(suffix='.wav', delete=False) as f:
                if ref_audio_b64:
                    f.write(base64.b64decode(ref_audio_b64))
                else:
                    import urllib.request
                    urllib.request.urlretrieve("https://github.com/coqui-ai/TTS/raw/dev/tests/data/ljspeech/wavs/LJ001-0001.wav", f.name)
                ref_path = f.name
            
            yield f"data: {json.dumps({'type': 'progress', 'current': 0, 'total': total, 'percent': 5, 'status': 'Voice loaded'})}\n\n"
            
            all_audio = []
            sr = 24000  # XTTSv2 sample rate
            silence = np.zeros(int(sr * 0.3), dtype=np.float32)  # 300ms gap between chunks
            
            for i, chunk in enumerate(chunks):
                pct = int(((i) / total) * 90) + 5
                yield f"data: {json.dumps({'type': 'progress', 'current': i, 'total': total, 'percent': pct, 'status': f'Chunk {i+1}/{total} ({len(chunk)} chars)...'})}\n\n"
                
                # Use tts_to_file with XTTS internal splitting for best results
                out_path = f"/tmp/xtts_chunk_{i}.wav"
                tts.tts_to_file(
                    text=chunk,
                    speaker_wav=ref_path,
                    language=lang_code,
                    file_path=out_path,
                    split_sentences=True
                )
                
                audio_chunk, chunk_sr = sf.read(out_path)
                all_audio.append(audio_chunk)
                if i < total - 1:
                    all_audio.append(silence)  # add gap between chunks
                os.unlink(out_path)
                
                pct = int(((i+1) / total) * 90) + 5
                yield f"data: {json.dumps({'type': 'progress', 'current': i+1, 'total': total, 'percent': pct, 'status': f'Chunk {i+1}/{total} done'})}\n\n"
            
            os.unlink(ref_path)
            
            combined = np.concatenate(all_audio)
            
            print('🧹 Cleaning audio...')
            final = clean_audio(combined, sr)
            
            buffer = io.BytesIO()
            sf.write(buffer, final, sr, format='WAV')
            buffer.seek(0)
            audio_b64 = base64.b64encode(buffer.read()).decode('utf-8')
            
            duration = len(final) / sr
            print(f"✅ {duration:.1f}s generated")
            
            yield f"data: {json.dumps({'type': 'complete', 'audio': audio_b64, 'duration': round(duration, 1)})}\n\n"
            
        except Exception as e:
            import traceback; traceback.print_exc()
            yield f"data: {json.dumps({'type': 'error', 'message': str(e)})}\n\n"
    
    if stream:
        return Response(generate_with_progress(), mimetype='text/event-stream', headers={'Cache-Control': 'no-cache'})
    else:
        try:
            with tempfile.NamedTemporaryFile(suffix='.wav', delete=False) as f:
                if ref_audio_b64:
                    f.write(base64.b64decode(ref_audio_b64))
                else:
                    import urllib.request
                    urllib.request.urlretrieve("https://github.com/coqui-ai/TTS/raw/dev/tests/data/ljspeech/wavs/LJ001-0001.wav", f.name)
                ref_path = f.name
            
            out_path = "/tmp/xtts_output.wav"
            tts.tts_to_file(text=text, speaker_wav=ref_path, language=lang_code, file_path=out_path, split_sentences=True)
            os.unlink(ref_path)
            
            audio, sr = sf.read(out_path)
            cleaned = clean_audio(audio, sr)
            sf.write(out_path, cleaned, sr, format='WAV')
            
            return send_file(out_path, mimetype='audio/wav')
        except Exception as e:
            return jsonify({"error": str(e)}), 500

public_url = ngrok.connect(5000)
print("\n" + "="*50)
print(f"🚀 XTTSv2 URL: {public_url}")
print("="*50 + "\n")

app.run(port=5000)
